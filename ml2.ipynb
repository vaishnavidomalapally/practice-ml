# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\Home\Favorites\Downloads\Advertising.csv")
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.shape
# Out:
# (200, 5)

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.sample()
# Out:
#      Unnamed: 0    TV  Radio  Newspaper  Sales
# 121         122  18.8   21.7       50.4    7.0

# %%
print(df.isnull().sum())
#missing values
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
import seaborn as sns

# %%
sns.histplot(x=df['TV'])
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=df['Radio'])
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(x=df['Newspaper'])
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(x=df['Sales'])
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
sns.histplot(x=df['Unnamed: 0'])
# Out:
# <Axes: xlabel='Unnamed: 0', ylabel='Count'>

# %%
sns.histplot(x=df['TV'],kde=True)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=df['TV'],kde=True,bins=40)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=df['Unnamed: 0'],kde=True,bins=40)
# Out:
# <Axes: xlabel='Unnamed: 0', ylabel='Count'>

# %%
sns.histplot(x=df['Radio'],kde=True,bins=40)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(x=df['Newspaper'],kde=True,bins=40)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(x=df['Sales'],kde=True,bins=40)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
df['TV'].skew()
# Out:
# np.float64(-0.06985336213274573)

# %%
df['Radio'].skew()
# Out:
# np.float64(0.09417463149664404)

# %%
df['Sales'].skew()
# Out:
# np.float64(0.4075714250767127)

# %%
df['Newspaper'].skew()
# Out:
# np.float64(0.8947204074986175)

# %%
df['Unnamed: 0'].skew()
# Out:
# np.float64(0.0)

# %%
#skew is 0 it is normal
#skew is +ve it is right
#skew is -ve it is left

# %%
sns.scatterplot(x='TV', y='Radio',data=df)
plt.show()#random

# %%
sns.scatterplot(x='TV', y='Newspaper',data=df)
plt.show()#random

# %%
sns.scatterplot(x='TV', y='Sales',data=df)
plt.show()#positive

# %%
sns.scatterplot(x='TV', y='Unnamed: 0',data=df)
plt.show()#random

# %%
sns.scatterplot(x='Unnamed: 0', y='TV',data=df)
plt.show()#random

# %%
sns.scatterplot(x='Unnamed: 0', y='Radio',data=df)
plt.show()#random

# %%
sns.scatterplot(x='Unnamed: 0', y='Newspaper',data=df)
plt.show()#random

# %%
sns.scatterplot(x='Unnamed: 0', y='Sales',data=df)
plt.show()#random

# %%
sns.scatterplot(x='Radio', y='TV',data=df)
plt.show()#random

# %%
sns.scatterplot(x='Radio', y='Newspaper',data=df)
plt.show()#random

# %%
sns.scatterplot(x='Radio', y='Sales',data=df)
plt.show()#positive

# %%
sns.scatterplot(x='Radio', y='Unnamed: 0',data=df)
plt.show()#random

# %%
df.corr()
# Out:
#             Unnamed: 0        TV     Radio  Newspaper     Sales
# Unnamed: 0    1.000000  0.017715 -0.110680  -0.154944 -0.051616
# TV            0.017715  1.000000  0.054809   0.056648  0.782224
# Radio        -0.110680  0.054809  1.000000   0.354104  0.576223
# Newspaper    -0.154944  0.056648  0.354104   1.000000  0.228299
# Sales        -0.051616  0.782224  0.576223   0.228299  1.000000

# %%
#insights
1.The positive values which are close to the zero are weak positive
2.The values which are far to the zero are strong positive
3.the negative values which are close to the zero are strong negatTve
4.The values whuch are far to the zero are the strong negative
5.The values between the strong positive and weak positive is said to be positive moderate
6.5.The values between the strong negative and weak negative is said to be negative moderate

# %%
sns.heatmap(df.corr(),annot=True,cmap='Greens')
# Out:
# <Axes: >

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x=df.drop('Sales',axis=1)
y=df.Sales

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
x=df[['TV']]
y=df.Sales

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.46138746336817515

# %%
print("MSE:",mean_squared_error(y_test,y_predict))
print("MAE:",mean_absolute_error(y_test,y_predict))
print("RMSE:",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE: 13.06226628830567
# MAE: 2.990565035759226
# RMSE: 3.6141757412037494

# %%
x=df[['Radio']]
y=df.Sales

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.37864501183785726

# %%
c
# Out:
# MSE: 15.068910882943161
# MAE: 3.2689170364697815
# RMSE: 3.881869508747449

# %%
x=df[['Newspaper']]
y=df.Sales

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# -0.11728796161004928

# %%
print("MSE:",mean_squared_error(y_test,y_predict))
print("MAE:",mean_absolute_error(y_test,y_predict))
print("RMSE:",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE: 27.09612547552867
# MAE: 3.992290912504232
# RMSE: 5.205393882841976

# %%
x=df[['TV','Radio','Newspaper']]
x=df.Sales

# %%
x
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
x=df[['TV','Radio','Newspaper']]
y=df.Sales

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.9085774752313167

# %%
print("MSE:",mean_squared_error(y_test,y_predict))
print("MAE:",mean_absolute_error(y_test,y_predict))
print("RMSE:",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE: 2.2171510725418955
# MAE: 1.21148926064691
# RMSE: 1.489010098200108

# %%
x=df[['TV','Radio']]
x=df.Sales

# %%
x
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
x=df[['TV','Radio']]
y=df.Sales

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=4)

# %%
print(len(x_test))
print(len(x_train))
# Out:
# 40
# 160

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()
LR.fit(x_train,y_train)
y_predict=LR.predict(x_test)

# %%
from sklearn.metrics import (r2_score,mean_squared_error,mean_absolute_error,root_mean_squared_error)
r2score=r2_score(y_test,y_predict)
r2score
# Out:
# 0.9086623887492479

# %%
print("MSE:",mean_squared_error(y_test,y_predict))
print("MAE:",mean_absolute_error(y_test,y_predict))
print("RMSE:",root_mean_squared_error(y_test,y_predict))
# Out:
# MSE: 2.2150917759097952
# MAE: 1.2108086204929325
# RMSE: 1.4883184390142437
